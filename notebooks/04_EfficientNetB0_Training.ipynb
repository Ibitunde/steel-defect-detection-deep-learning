# %%
"""
================================================================================
STEEL SURFACE DEFECT DETECTION PROJECT
NOTEBOOK 4: EfficientNetB0 TRAINING

Author: Mayowa Oluwaseun Ibitunde
Student ID: 23096291
Programme: MSc Data Science
University: University of Hertfordshire
Supervisor: Vito Graffagnino

Purpose:
- Train EfficientNetB0 model with transfer learning
- Compare with VGG16 (99.44%) and ResNet50 (98.06%)
- Evaluate and save results
================================================================================
"""

# ============================================================================
# SECTION 1: MOUNT GOOGLE DRIVE AND SETUP
# ============================================================================

print("="*80)
print("STEEL SURFACE DEFECT DETECTION - EfficientNetB0 TRAINING")
print("="*80)
print()

from google.colab import drive
drive.mount('/content/drive')

print("✓ Google Drive mounted!")
print()

# Check GPU availability
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
else:
    print("⚠️ WARNING: No GPU detected! Training will be slow.")
    print("   Go to Runtime → Change runtime type → Select GPU")

print("="*80)
print()


# ============================================================================
# SECTION 2: IMPORT LIBRARIES
# ============================================================================

import os
import random
import shutil
import time
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from collections import defaultdict

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from PIL import Image
from tqdm.auto import tqdm

print("✓ All libraries imported successfully!")
print()


# ============================================================================
# SECTION 3: SET RANDOM SEEDS FOR REPRODUCIBILITY
# ============================================================================

def set_seed(seed=42):
    """Set random seeds for reproducibility."""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)
print("✓ Random seed set to 42 for reproducibility")
print()


# ============================================================================
# SECTION 4: DEFINE PATHS
# ============================================================================

# Dataset paths
SPLIT_DIR = Path('/content/drive/MyDrive/FINAL PROJECT/NEU-Split')
RESULTS_DIR = Path('/content/drive/MyDrive/FINAL PROJECT/Results')

# Create directories
RESULTS_DIR.mkdir(exist_ok=True)
(RESULTS_DIR / 'models').mkdir(exist_ok=True)
(RESULTS_DIR / 'figures').mkdir(exist_ok=True)

print(f"Split data: {SPLIT_DIR}")
print(f"Results: {RESULTS_DIR}")
print()


# ============================================================================
# SECTION 5: PYTORCH DATASET CLASS
# ============================================================================

class SteelDefectDataset(Dataset):
    """
    PyTorch Dataset for NEU Steel Surface Defect Classification.

    Args:
        root_dir (str): Directory containing class folders
        transform (callable, optional): Transform to apply to images
    """

    def __init__(self, root_dir, transform=None):
        self.root_dir = Path(root_dir)
        self.transform = transform

        # Get class names and create mapping
        self.classes = sorted([d.name for d in self.root_dir.iterdir() if d.is_dir()])
        self.class_to_idx = {cls: idx for idx, cls in enumerate(self.classes)}

        # Load all image paths and labels
        self.samples = self._load_samples()

    def _load_samples(self):
        """Load all image file paths and their labels."""
        samples = []
        for class_name in self.classes:
            class_dir = self.root_dir / class_name
            class_idx = self.class_to_idx[class_name]

            for img_path in class_dir.glob('*.bmp'):
                samples.append((str(img_path), class_idx))

        return samples

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, label = self.samples[idx]

        # Load image and convert to RGB
        image = Image.open(img_path).convert('RGB')

        # Apply transforms if provided
        if self.transform:
            image = self.transform(image)

        return image, label

print("✓ PyTorch Dataset class defined")
print()


# ============================================================================
# SECTION 6: DATA TRANSFORMS (EfficientNet uses 224x224)
# ============================================================================

# Training transforms (with augmentation)
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),  # EfficientNetB0 default input size
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                        std=[0.229, 0.224, 0.225])
])

# Validation/Test transforms (NO augmentation)
val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                        std=[0.229, 0.224, 0.225])
])

print("✓ Data augmentation transforms defined")
print()


# ============================================================================
# SECTION 7: CREATE DATASETS AND DATALOADERS
# ============================================================================

# Create datasets
train_dataset = SteelDefectDataset(SPLIT_DIR / 'train', transform=train_transform)
val_dataset = SteelDefectDataset(SPLIT_DIR / 'val', transform=val_transform)
test_dataset = SteelDefectDataset(SPLIT_DIR / 'test', transform=val_transform)

# Create dataloaders
BATCH_SIZE = 32
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True,
                         num_workers=0, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False,
                       num_workers=0, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False,
                        num_workers=0, pin_memory=True)

print("="*80)
print("DATASET LOADED")
print("="*80)
print(f"Training samples:   {len(train_dataset):4d}")
print(f"Validation samples: {len(val_dataset):4d}")
print(f"Test samples:       {len(test_dataset):4d}")
print(f"Number of classes:  {len(train_dataset.classes)}")
print(f"Classes: {train_dataset.classes}")
print(f"Batch size: {BATCH_SIZE}")
print("="*80)
print()


# ============================================================================
# SECTION 8: CREATE EfficientNetB0 MODEL
# ============================================================================

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Load pre-trained EfficientNetB0 (trained on ImageNet)
model = models.efficientnet_b0(pretrained=True)

# Freeze all layers except the classifier
for param in model.parameters():
    param.requires_grad = False

# Replace classifier for our 6 classes
# EfficientNetB0 classifier structure: Sequential(Dropout, Linear)
num_features = model.classifier[1].in_features  # 1280 for EfficientNetB0
model.classifier = nn.Sequential(
    nn.Dropout(p=0.2, inplace=True),
    nn.Linear(num_features, 6)  # 6 output classes
)

model = model.to(device)

print("="*80)
print("EfficientNetB0 MODEL ARCHITECTURE")
print("="*80)
print(f"Device: {device}")
print(f"Model: EfficientNetB0 (pre-trained on ImageNet)")
print(f"Feature layers: Frozen (not trainable)")
print(f"Classifier: Fine-tuned for 6 steel defect classes")
print()

total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"Total parameters: {total_params:,}")
print(f"Trainable parameters: {trainable_params:,}")
print(f"Frozen parameters: {total_params - trainable_params:,}")
print("="*80)
print()


# ============================================================================
# SECTION 9: TRAINING SETUP
# ============================================================================

# Loss function
criterion = nn.CrossEntropyLoss()

# Optimizer (only optimize trainable parameters)
optimizer = optim.Adam(
    filter(lambda p: p.requires_grad, model.parameters()),
    lr=0.001
)

# Learning rate scheduler
scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='min',
    factor=0.5,
    patience=5
)

print("✓ Training setup complete")
print(f"  Loss function: CrossEntropyLoss")
print(f"  Optimizer: Adam (lr=0.001)")
print(f"  LR Scheduler: ReduceLROnPlateau (patience=5)")
print()


# ============================================================================
# SECTION 10: TRAINING FUNCTIONS
# ============================================================================

def train_one_epoch(model, train_loader, criterion, optimizer, device):
    """Train model for one epoch."""
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    pbar = tqdm(train_loader, desc='Training', leave=False)
    for images, labels in pbar:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()

        pbar.set_postfix({
            'loss': f'{loss.item():.4f}',
            'acc': f'{100.*correct/total:.2f}%'
        })

    avg_loss = running_loss / len(train_loader)
    accuracy = 100. * correct / total

    return avg_loss, accuracy


def evaluate(model, data_loader, criterion, device):
    """Evaluate model on validation or test set."""
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

    avg_loss = running_loss / len(data_loader)
    accuracy = 100. * correct / total

    return avg_loss, accuracy

print("✓ Training and evaluation functions defined")
print()


# ============================================================================
# SECTION 11: TRAIN THE MODEL
# ============================================================================

print("="*80)
print("STARTING TRAINING - EfficientNetB0")
print("="*80)
print()

NUM_EPOCHS = 25
best_val_acc = 0.0
history = {
    'train_loss': [],
    'train_acc': [],
    'val_loss': [],
    'val_acc': []
}

start_time = time.time()

for epoch in range(NUM_EPOCHS):
    print(f"Epoch [{epoch+1}/{NUM_EPOCHS}]")

    # Train
    train_loss, train_acc = train_one_epoch(model, train_loader, criterion, optimizer, device)

    # Validate
    val_loss, val_acc = evaluate(model, val_loader, criterion, device)

    # Update learning rate
    scheduler.step(val_loss)

    # Save history
    history['train_loss'].append(train_loss)
    history['train_acc'].append(train_acc)
    history['val_loss'].append(val_loss)
    history['val_acc'].append(val_acc)

    # Print results
    print(f"  Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}%")
    print(f"  Val Loss:   {val_loss:.4f} | Val Acc:   {val_acc:.2f}%")

    # Save best model
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'val_acc': val_acc,
            'val_loss': val_loss,
        }, RESULTS_DIR / 'models/efficientnet_b0_best.pth')
        print(f"  ✓ Best model saved (Val Acc: {val_acc:.2f}%)")

    print()

total_time = time.time() - start_time

print("="*80)
print("TRAINING COMPLETE!")
print("="*80)
print(f"Total time: {total_time/60:.1f} minutes")
print(f"Best validation accuracy: {best_val_acc:.2f}%")
print("="*80)
print()


# ============================================================================
# SECTION 12: PLOT TRAINING HISTORY
# ============================================================================

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

epochs_range = range(1, NUM_EPOCHS + 1)

# Loss plot
ax1.plot(epochs_range, history['train_loss'], 'b-', label='Training Loss', linewidth=2)
ax1.plot(epochs_range, history['val_loss'], 'r-', label='Validation Loss', linewidth=2)
ax1.set_xlabel('Epoch', fontsize=12)
ax1.set_ylabel('Loss', fontsize=12)
ax1.set_title('EfficientNetB0: Training and Validation Loss', fontsize=14, fontweight='bold')
ax1.legend(fontsize=10)
ax1.grid(True, alpha=0.3)

# Accuracy plot
ax2.plot(epochs_range, history['train_acc'], 'b-', label='Training Accuracy', linewidth=2)
ax2.plot(epochs_range, history['val_acc'], 'r-', label='Validation Accuracy', linewidth=2)
ax2.set_xlabel('Epoch', fontsize=12)
ax2.set_ylabel('Accuracy (%)', fontsize=12)
ax2.set_title('EfficientNetB0: Training and Validation Accuracy', fontsize=14, fontweight='bold')
ax2.legend(fontsize=10)
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(RESULTS_DIR / 'figures/efficientnet_b0_training_curves.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ Training curves saved!")
print()


# ============================================================================
# SECTION 13: EVALUATE ON TEST SET
# ============================================================================

# Load best model
checkpoint = torch.load(RESULTS_DIR / 'models/efficientnet_b0_best.pth')
model.load_state_dict(checkpoint['model_state_dict'])

# Evaluate on test set
test_loss, test_acc = evaluate(model, test_loader, criterion, device)

print("="*80)
print("FINAL TEST RESULTS - EfficientNetB0")
print("="*80)
print(f"Test Loss:     {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.2f}%")
print()
print("COMPARISON WITH PREVIOUS MODELS:")
print(f"  VGG16:          99.44%")
print(f"  ResNet50:       98.06%")
print(f"  EfficientNetB0: {test_acc:.2f}%")
print("="*80)
print()

# Save results to file
results_text = f"""
EfficientNetB0 - STEEL DEFECT DETECTION RESULTS
================================================

Training Configuration:
- Model: EfficientNetB0 (pre-trained on ImageNet)
- Dataset: NEU Surface Defect Database
- Classes: 6 (crazing, inclusion, patches, pitted_surface, rolled_in_scale, scratches)
- Training samples: {len(train_dataset)}
- Validation samples: {len(val_dataset)}
- Test samples: {len(test_dataset)}
- Epochs: {NUM_EPOCHS}
- Batch size: {BATCH_SIZE}
- Optimizer: Adam (lr=0.001)
- Data augmentation: RandomFlip, Rotation, ColorJitter

Final Results:
- Best Validation Accuracy: {best_val_acc:.2f}%
- Test Accuracy: {test_acc:.2f}%
- Test Loss: {test_loss:.4f}
- Training time: {total_time/60:.1f} minutes

Comparison with Other Models:
- VGG16: 99.44%
- ResNet50: 98.06%
- EfficientNetB0: {test_acc:.2f}%
"""

with open(RESULTS_DIR / 'efficientnet_b0_results.txt', 'w') as f:
    f.write(results_text)

print("✓ Results saved to efficientnet_b0_results.txt")
print()

print("="*80)
print("🎉 EfficientNetB0 TRAINING COMPLETE! 🎉")
print("="*80)
print()
print("Files saved:")
print(f"  ✓ Model: {RESULTS_DIR}/models/efficientnet_b0_best.pth")
print(f"  ✓ Training curves: {RESULTS_DIR}/figures/efficientnet_b0_training_curves.png")
print(f"  ✓ Results summary: {RESULTS_DIR}/efficientnet_b0_results.txt")
print()
print("Next model: MobileNetV3-Small")
print("="*80)
# Out:
# ================================================================================
# STEEL SURFACE DEFECT DETECTION - EfficientNetB0 TRAINING
# ================================================================================
#
# Mounted at /content/drive
# ✓ Google Drive mounted!
#
# PyTorch version: 2.10.0+cu128
# CUDA available: True
# GPU: Tesla T4
# GPU Memory: 15.6 GB
# ================================================================================
#
# ✓ All libraries imported successfully!
#
# ✓ Random seed set to 42 for reproducibility
#
# Split data: /content/drive/MyDrive/FINAL PROJECT/NEU-Split
# Results: /content/drive/MyDrive/FINAL PROJECT/Results
#
# ✓ PyTorch Dataset class defined
#
# ✓ Data augmentation transforms defined
#
# ================================================================================
# DATASET LOADED
# ================================================================================
# Training samples:   1260
# Validation samples:  180
# Test samples:        360
# Number of classes:  6
# Classes: ['crazing', 'inclusion', 'patches', 'pitted_surface', 'rolled_in_scale', 'scratches']
# Batch size: 32
# ================================================================================
#
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 141MB/s]
# ================================================================================
# EfficientNetB0 MODEL ARCHITECTURE
# ================================================================================
# Device: cuda
# Model: EfficientNetB0 (pre-trained on ImageNet)
# Feature layers: Frozen (not trainable)
# Classifier: Fine-tuned for 6 steel defect classes
#
# Total parameters: 4,015,234
# Trainable parameters: 7,686
# Frozen parameters: 4,007,548
# ================================================================================
#
# ✓ Training setup complete
#   Loss function: CrossEntropyLoss
#   Optimizer: Adam (lr=0.001)
#   LR Scheduler: ReduceLROnPlateau (patience=5)
#
# ✓ Training and evaluation functions defined
#
# ================================================================================
# STARTING TRAINING - EfficientNetB0
# ================================================================================
#
# Epoch [1/25]
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
#   Train Loss: 0.9478 | Train Acc: 77.70%
#   Val Loss:   0.5489 | Val Acc:   95.00%
#   ✓ Best model saved (Val Acc: 95.00%)
#
# Epoch [2/25]
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
#   Train Loss: 0.3546 | Train Acc: 94.68%
#   Val Loss:   0.2484 | Val Acc:   97.22%
#   ✓ Best model saved (Val Acc: 97.22%)
#
# Epoch [3/25]
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
#   Train Loss: 0.2652 | Train Acc: 94.52%
#   Val Loss:   0.1707 | Val Acc:   97.78%
#   ✓ Best model saved (Val Acc: 97.78%)
#
# Epoch [4/25]
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
#   Train Loss: 0.1851 | Train Acc: 96.59%
#   Val Loss:   0.1380 | Val Acc:   97.78%
#
# Epoch [5/25]
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
#   Train Loss: 0.1822 | Train Acc: 95.95%
#   Val Loss:   0.1278 | Val Acc:   97.78%
#
# Epoch [6/25]
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
#   Train Loss: 0.1483 | Train Acc: 96.90%
#   Val Loss:   0.0918 | Val Acc:   98.33%
#   ✓ Best model saved (Val Acc: 98.33%)
#
# Epoch [7/25]
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
#   Train Loss: 0.1380 | Train Acc: 97.22%
#   Val Loss:   0.0846 | Val Acc:   98.33%
#
# Epoch [8/25]
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
#   Train Loss: 0.1281 | Train Acc: 96.90%
#   Val Loss:   0.0817 | Val Acc:   97.78%
#
# Epoch [9/25]
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
#   Train Loss: 0.1124 | Train Acc: 97.06%
#   Val Loss:   0.0751 | Val Acc:   98.89%
#   ✓ Best model saved (Val Acc: 98.89%)
#
# Epoch [10/25]
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
#   Train Loss: 0.1032 | Train Acc: 97.78%
#   Val Loss:   0.0721 | Val Acc:   98.33%
#
# Epoch [11/25]
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
#   Train Loss: 0.0938 | Train Acc: 97.78%
#   Val Loss:   0.0654 | Val Acc:   97.78%
#
# Epoch [12/25]
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
#   Train Loss: 0.0937 | Train Acc: 97.54%
#   Val Loss:   0.0637 | Val Acc:   98.89%
#
# Epoch [13/25]
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
#   Train Loss: 0.0773 | Train Acc: 98.65%
#   Val Loss:   0.0616 | Val Acc:   98.33%
#
# Epoch [14/25]
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
#   Train Loss: 0.1108 | Train Acc: 96.83%
#   Val Loss:   0.0741 | Val Acc:   97.78%
#
# Epoch [15/25]
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
#   Train Loss: 0.0983 | Train Acc: 97.62%
#   Val Loss:   0.0646 | Val Acc:   97.78%
#
# Epoch [16/25]
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
#   Train Loss: 0.0744 | Train Acc: 98.25%
#   Val Loss:   0.0584 | Val Acc:   98.33%
#
# Epoch [17/25]
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
#   Train Loss: 0.0736 | Train Acc: 98.25%
#   Val Loss:   0.0589 | Val Acc:   97.78%
#
# Epoch [18/25]
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
#   Train Loss: 0.0693 | Train Acc: 98.10%
#   Val Loss:   0.0541 | Val Acc:   98.33%
#
# Epoch [19/25]
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
#   Train Loss: 0.0714 | Train Acc: 97.86%
#   Val Loss:   0.0534 | Val Acc:   98.33%
#
# Epoch [20/25]
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
#   Train Loss: 0.0670 | Train Acc: 98.25%
#   Val Loss:   0.0524 | Val Acc:   98.33%
#
# Epoch [21/25]
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
#   Train Loss: 0.0631 | Train Acc: 98.33%
#   Val Loss:   0.0524 | Val Acc:   97.78%
#
# Epoch [22/25]
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
#   Train Loss: 0.0732 | Train Acc: 97.46%
#   Val Loss:   0.0496 | Val Acc:   98.33%
#
# Epoch [23/25]
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
#   Train Loss: 0.0572 | Train Acc: 98.57%
#   Val Loss:   0.0391 | Val Acc:   98.89%
#
# Epoch [24/25]
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
#   Train Loss: 0.0711 | Train Acc: 97.94%
#   Val Loss:   0.0503 | Val Acc:   97.78%
#
# Epoch [25/25]
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
#   Train Loss: 0.0591 | Train Acc: 98.65%
#   Val Loss:   0.0486 | Val Acc:   98.33%
#
# ================================================================================
# TRAINING COMPLETE!
# ================================================================================
# Total time: 16.3 minutes
# Best validation accuracy: 98.89%
# ================================================================================
# ✓ Training curves saved!
#
# ================================================================================
# FINAL TEST RESULTS - EfficientNetB0
# ================================================================================
# Test Loss:     0.0789
# Test Accuracy: 99.17%
#
# COMPARISON WITH PREVIOUS MODELS:
#   VGG16:          99.44%
#   ResNet50:       98.06%
#   EfficientNetB0: 99.17%
# ================================================================================
#
# ✓ Results saved to efficientnet_b0_results.txt
#
# ================================================================================
# 🎉 EfficientNetB0 TRAINING COMPLETE! 🎉
# ================================================================================
#
# Files saved:
#   ✓ Model: /content/drive/MyDrive/FINAL PROJECT/Results/models/efficientnet_b0_best.pth
#   ✓ Training curves: /content/drive/MyDrive/FINAL PROJECT/Results/figures/efficientnet_b0_training_curves.png
#   ✓ Results summary: /content/drive/MyDrive/FINAL PROJECT/Results/efficientnet_b0_results.txt
#
# Next model: MobileNetV3-Small
# ================================================================================
